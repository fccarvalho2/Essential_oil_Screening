# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv ('similarityMatrix-OambAntagonistaDecoys.csv', index_col = 'Unnamed: 0', sep=';')
#data = read.csv2('similarityMatrix-OLEO.csv', header = TRUE, sep = ";")

# %%
df
# Out:
#            C00644735  C08832021  C10267032  C07423473  C13149194  C08442141  \
# C00644735   1.000000   0.234940   0.329787   0.301659   0.321908   0.321401
# C08832021   0.234940   1.000000   0.273610   0.259095   0.347107   0.209145
# C10267032   0.329787   0.273610   1.000000   0.392771   0.364472   0.277859
# C07423473   0.301659   0.259095   0.392771   1.000000   0.341985   0.295403
# C13149194   0.321908   0.347107   0.364472   0.341985   1.000000   0.284157
# ...              ...        ...        ...        ...        ...        ...
# C94938846   0.196537   0.172301   0.197244   0.218555   0.215821   0.226583
# C94939002   0.149635   0.145433   0.162236   0.172479   0.166065   0.172123
# C96420051   0.114674   0.105263   0.121359   0.133267   0.110169   0.102515
# C97433566   0.129126   0.116037   0.125962   0.125613   0.131629   0.120155
# C97873182   0.235696   0.292517   0.251075   0.233621   0.243902   0.216216
#
# ...

# %%
df.columns[-1]
# Out:
# 'Unnamed: 701'

# %%
with open('tanimoto.log', 'w+') as logfile:
    for c in df.columns:
        a = len(df.loc[df[c] == 1])
        if a > 1:
            msg = ''.join([str(c), '\tpossui ', str(a), ' índices  iguais a 1:'])
            logfile.write(msg)
            print(c, '\tpossui ', a, 'índices  iguais a 1:', end = ' ')
            for b in list(df.loc[df[c] == 1].index):
                if b  != list(df.loc[df[c] == 1].index)[-1]:
                    msg = ''.join([str(b), ','])
                    logfile.write(msg)
                    print(b, end = ',')
                else:
                    print(b)
                    msg = ''.join([str(b), '\n'])
                    logfile.write(msg)
# Out:
# C36325152 	possui  2 índices  iguais a 1: C36325152
# C36325152
# C97611579 	possui  2 índices  iguais a 1: C97611579,C97611578
# C36325152.1 	possui  2 índices  iguais a 1: C36325152
# C36325152
# C97611578 	possui  2 índices  iguais a 1: C97611579,C97611578
# C86303523 	possui  2 índices  iguais a 1: C86303523,C86303526
# C86303526 	possui  2 índices  iguais a 1: C86303523,C86303526
# C87836686 	possui  2 índices  iguais a 1: C87836686,C87836683
# C87836683 	possui  2 índices  iguais a 1: C87836686,C87836683
# C52123438 	possui  2 índices  iguais a 1: C52123438,C52123439
# C52123439 	possui  2 índices  iguais a 1: C52123438,C52123439
# C61631402 	possui  2 índices  iguais a 1: C61631402,C61631403
# C61631403 	possui  2 índices  iguais a 1: C61631402,C61631403
# C94434700 	possui  2 índices  iguais a 1: C94434700
# C94434700
# C94434700.1 	possui  2 índices  iguais a 1: C94434700
# C94434700
# C04000440 	possui  2 índices  iguais a 1: C04000440,C04000441
# ...

# %%
for c in df.columns:
    a = len(df.loc[df[c] == 1])
    if a > 1:
        print(c, 'possui ', a, 'índices  iguais a 1')
# Out:
# C86841779 possui  2 índices  iguais a 1
# C88040143 possui  2 índices  iguais a 1
# C45176511 possui  2 índices  iguais a 1
# C70622095 possui  2 índices  iguais a 1
# C70622097 possui  2 índices  iguais a 1
# C50814221 possui  2 índices  iguais a 1
# C50814222 possui  2 índices  iguais a 1
# C86578346 possui  2 índices  iguais a 1
# C86578348 possui  2 índices  iguais a 1
# C39097646 possui  2 índices  iguais a 1
# C45176509 possui  2 índices  iguais a 1
# C39097648 possui  2 índices  iguais a 1
# C51397891 possui  2 índices  iguais a 1
# C51397892 possui  2 índices  iguais a 1
# C50372286 possui  2 índices  iguais a 1
# C50372288 possui  2 índices  iguais a 1
# C83387383 possui  2 índices  iguais a 1
# C83460737 possui  2 índices  iguais a 1
# C84901553 possui  2 índices  iguais a 1
# C82802548 possui  2 índices  iguais a 1
# C83084973 possui  2 índices  iguais a 1
# C83084975 possui  2 índices  iguais a 1
# C83473077 possui  2 índices  iguais a 1
# ...

# %%
b = list(df.columns)
b
# Out:
# ['Decoy1',
#  'Decoy2',
#  'Decoy3',
#  'Decoy4',
#  'Decoy5',
#  'Decoy6',
#  'Decoy7',
#  'Decoy8',
#  'Decoy9',
#  'Decoy10',
#  'Decoy11',
#  'Decoy12',
#  'Decoy13',
#  'Decoy14',
#  'Decoy15',
#  'Decoy16',
#  'Decoy17',
#  'Decoy18',
#  'Decoy19',
#  'Decoy20',
#  'Decoy21',
#  'Decoy22',
#  'Decoy23',
#  'Decoy24',
#  'Decoy25',
#  'Decoy26',
#  'Decoy27',
#  'Decoy28',
#  'Decoy29',
#  'Decoy30',
#  'Decoy31',
#  'Decoy32',
#  'Decoy33',
#  'Decoy34',
#  'Decoy35',
#  'Decoy36',
#  'Decoy37',
#  'Decoy38',
#  'Decoy39',
#  'Decoy40',
#  'Decoy41',
#  'Decoy42',
#  'Decoy43',
#  'Decoy44',
#  'Decoy45',
#  'Decoy46',
#  'Decoy47',
#  'Decoy48',
#  'Decoy49',
#  'Decoy50',
#  'Decoy51',
#  'Decoy52',
#  'Decoy53',
#  'Decoy54',
#  'Decoy55',
#  'Decoy56',
#  'Decoy57',
#  'Decoy58',
#  'Decoy59',
#  'Decoy60',
#  'Decoy61',
#  'Decoy62',
#  'Decoy63',
#  'Decoy64',
#  'Decoy65',
#  'Decoy66',
#  'Decoy67',
#  'Decoy68',
#  'Decoy69',
#  'Decoy70',
#  'Decoy71',
#  'Decoy72',
# ...

# %%
ligantes = ['Decoy1', 'Decoy2',
 'Decoy3', 'Decoy4',
 'Decoy5', 'Decoy6',
 'Decoy7', 'Decoy8',
 'Decoy9', 'Decoy10',
 'Decoy11', 'Decoy12',
 'Decoy13', 'Decoy14',
 'Decoy15', 'Decoy16',
 'Decoy17', 'Decoy18',
 'Decoy19', 'Decoy20',
 'Decoy21', 'Decoy22',
 'Decoy23', 'Decoy24',
 'Decoy25', 'Decoy26',
 'Decoy27', 'Decoy28',
 'Decoy29', 'Decoy30',
 'Decoy31', 'Decoy32',
 'Decoy33', 'Decoy34',
 'Decoy35', 'Decoy36',
 'Decoy37', 'Decoy38',
 'Decoy39', 'Decoy40',
 'Decoy41', 'Decoy42',
 'Decoy43', 'Decoy44',
 'Decoy45', 'Decoy46',
 'Decoy47', 'Decoy48',
 'Decoy49', 'Decoy50',
 'Decoy51', 'Decoy52',
 'Decoy53', 'Decoy54',
 'Decoy55', 'Decoy56',
 'Decoy57', 'Decoy58',
 'Decoy59', 'Decoy60',
 'Decoy61', 'Decoy62',
 'Decoy63', 'Decoy64',
 'Decoy65', 'Decoy66',
 'Decoy67', 'Decoy68',
 'Decoy69', 'Decoy70',
 'Decoy71', 'Decoy72',
 'Decoy73', 'Decoy74',
 'Decoy75', 'Decoy76',
 'Decoy77', 'Decoy78',
 'Decoy79', 'Decoy80',
 'Decoy81', 'Decoy82',
 'Decoy83', 'Decoy84',
 'Decoy85', 'Decoy86',
 'Decoy87', 'Decoy88',
 'Decoy89', 'Decoy90',
 'Decoy91', 'Decoy92',
 'Decoy93', 'Decoy94',
 'Decoy95', 'Decoy96',
 'Decoy97', 'Decoy98',
 'Decoy99','Decoy100',
 'Decoy101','Decoy102', 'Decoy103',
 'Decoy104','Decoy105',
 'Decoy106','Decoy107',
 'Decoy108','Decoy109',
 'Decoy110','Decoy111',
 'Decoy112',
 'Decoy113',
 'Decoy114',
 'Decoy115',
 'Decoy116',
 'Decoy117',
 'Decoy118',
 'Decoy119',
 'Decoy120',
 'Decoy121',
 'Decoy122',
 'Decoy123',
 'Decoy124',
 'Decoy125',
 'Decoy126',
 'Decoy127',
 'Decoy128',
 'Decoy129',
 'Decoy130',
 'Decoy131',
 'Decoy132',
 'Decoy133',
 'Decoy134',
 'Decoy135',
 'Decoy136',
 'Decoy137',
 'Decoy138',
 'Decoy139',
 'Decoy140',
 'Decoy141',
 'Decoy142',
 'Decoy143',
 'Decoy144',
 'Decoy145',
 'Decoy146',
 'Decoy147',
 'Decoy148',
 'Decoy149',
 'Decoy150',
 'Decoy151',
 'Decoy152',
 'Decoy153',
 'Decoy154',
 'Decoy155',
 'Decoy156',
 'Decoy157',
 'Decoy158',
 'Decoy159',
 'Decoy160',
 'Decoy161',
 'Decoy162',
 'Decoy163',
 'Decoy164',
 'Decoy165',
 'Decoy166',
 'Decoy167',
 'Decoy168',
 'Decoy169',
 'Decoy170',
 'Decoy171',
 'Decoy172',
 'Decoy173',
 'Decoy174',
 'Decoy175',
 'Decoy176',
 'Decoy177',
 'Decoy178',
 'Decoy179',
 'Decoy180',
 'Decoy181',
 'Decoy182',
 'Decoy183',
 'Decoy184',
 'Decoy185',
 'Decoy186',
 'Decoy187',
 'Decoy188',
 'Decoy189',
 'Decoy190',
 'Decoy191',
 'Decoy192',
 'Decoy193',
 'Decoy194',
 'Decoy195',
 'Decoy196',
 'Decoy197',
 'Decoy198',
 'Decoy199',
 'Decoy200',
 'Decoy201',
 'Decoy202',
 'Decoy203',
 'Decoy204',
 'Decoy205',
 'Decoy206',
 'Decoy207',
 'Decoy208',
 'Decoy209',
 'Decoy210',
 'Decoy211',
 'Decoy212',
 'Decoy213',
 'Decoy214',
 'Decoy215',
 'Decoy216',
 'Decoy217',
 'Decoy218',
 'Decoy219',
 'Decoy220',
 'Decoy221',
 'Decoy222',
 'Decoy223',
 'Decoy224',
 'Decoy225',
 'Decoy226',
 'Decoy227',
 'Decoy228',
 'Decoy229',
 'Decoy230',
 'Decoy231',
 'Decoy232',
 'Decoy233',
 'Decoy234',
 'Decoy235',
 'Decoy236',
 'Decoy237',
 'Decoy238',
 'Decoy239',
 'Decoy240',
 'Decoy241',
 'Decoy242',
 'Decoy243',
 'Decoy244',
 'Decoy245',
 'Decoy246',
 'Decoy247',
 'Decoy248',
 'Decoy249',
 'Decoy250',
 'Decoy251',
 'Decoy252',
 'Decoy253',
 'Decoy254',
 'Decoy255',
 'Decoy256',
 'Decoy257',
 'Decoy258',
 'Decoy259',
 'Decoy260',
 'Decoy261',
 'Decoy262',
 'Decoy263',
 'Decoy264',
 'Decoy265',
 'Decoy266',
 'Decoy267',
 'Decoy268',
 'Decoy269',
 'Decoy270',
 'Decoy271',
 'Decoy272',
 'Decoy273',
 'Decoy274',
 'Decoy275',
 'Decoy276',
 'Decoy277',
 'Decoy278',
 'Decoy279',
 'Decoy280',
 'Decoy281',
 'Decoy282',
 'Decoy283',
 'Decoy284',
 'Decoy285',
 'Decoy286',
 'Decoy287',
 'Decoy288',
 'Decoy289',
 'Decoy290',
 'Decoy291',
 'Decoy292',
 'Decoy293',
 'Decoy294',
 'Decoy295',
 'Decoy296',
 'Decoy297',
 'Decoy298',
 'Decoy299',
 'Decoy300',
 'Decoy301',
 'Decoy302',
 'Decoy303',
 'Decoy304',
 'Decoy305',
 'Decoy306',
 'Decoy307',
 'Decoy308',
 'Decoy309',
 'Decoy310',
 'Decoy311',
 'Decoy312',
 'Decoy313',
 'Decoy314',
 'Decoy315',
 'Decoy316',
 'Decoy317',
 'Decoy318',
 'Decoy319',
 'Decoy320',
 'Decoy321',
 'Decoy322',
 'Decoy323',
 'Decoy324',
 'Decoy325',
 'Decoy326',
 'Decoy327',
 'Decoy328',
 'Decoy329',
 'Decoy330',
 'Decoy331',
 'Decoy332',
 'Decoy333',
 'Decoy334',
 'Decoy335',
 'Decoy336',
 'Decoy337',
 'Decoy338',
 'Decoy339',
 'Decoy340',
 'Decoy341',
 'Decoy342',
 'Decoy343',
 'Decoy344',
 'Decoy345',
 'Decoy346',
 'Decoy347',
 'Decoy348',
 'Decoy349',
 'Decoy350',
 'Decoy351',
 'Decoy352',
 'Decoy353',
 'Decoy354',
 'Decoy355',
 'Decoy356',
 'Decoy357',
 'Decoy358',
 'Decoy359',
 'Decoy360',
 'Decoy361',
 'Decoy362',
 'Decoy363',
 'Decoy364',
 'Decoy365',
 'Decoy366',
 'Decoy367',
 'Decoy368',
 'Decoy369',
 'Decoy370',
 'Decoy371',
 'Decoy372',
 'Decoy373',
 'Decoy374',
 'Decoy375',
 'Decoy376',
 'Decoy377',
 'Decoy378',
 'Decoy379',
 'Decoy380',
 'Decoy381',
 'Decoy382',
 'Decoy383',
 'Decoy384',
 'Decoy385',
 'Decoy386',
 'Decoy387',
 'Decoy388',
 'Decoy389',
 'Decoy390',
 'Decoy391',
 'Decoy392',
 'Decoy393',
 'Decoy394',
 'Decoy395',
 'Decoy396',
 'Decoy397',
 'Decoy398',
 'Decoy399',
 'Decoy400',
 'Decoy402',
 'Decoy403',
 'Decoy404',
 'Decoy405',
 'Decoy406',
 'Decoy407',
 'Decoy408',
 'Decoy409',
 'Decoy410',
 'Decoy411',
 'Decoy412',
 'Decoy413',
 'Decoy414',
 'Decoy415',
 'Decoy416',
 'Decoy417',
 'Decoy418',
 'Decoy419',
 'Decoy420',
 'Decoy421',
 'Decoy422',
 'Decoy423',
 'Decoy424',
 'Decoy425',
 'Decoy426',
 'Decoy427',
 'Decoy428',
 'Decoy429',
 'Decoy430',
 'Decoy431',
 'Decoy432',
 'Decoy433',
 'Decoy434',
 'Decoy435',
 'Decoy436',
 'Decoy437',
 'Decoy438',
 'Decoy439',
 'Decoy440',
 'Decoy441',
 'Decoy442',
 'Decoy443',
 'Decoy444',
 'Decoy445',
 'Decoy446',
 'Decoy447',
 'Decoy448',
 'Decoy449',
 'Decoy450',
 'Decoy451',
 'SEMNOME1',
 'Decoy453',
 'SEMNOME3',
 'SEMNOME4',
 'SEMNOME5',
 'SEMNOME6',
 'SEMNOME7',
 'SEMNOME8',
 'SEMNOME9',
 'SEMNOME10',
 'SEMNOME11',
 'SEMNOME12',
 'SEMNOME13',
 'SEMNOME14',
 'SEMNOME15',
 'SEMNOME16',
 'SEMNOME17',
 'SEMNOME18',
 'SEMNOME19',
 'SEMNOME20',
 'SEMNOME21',
 'SEMNOME22',
 'SEMNOME23',
 'SEMNOME24',
 'SEMNOME25',
 'SEMNOME26',
 'SEMNOME27',
 'SEMNOME28',
 'SEMNOME29',
 'SEMNOME30',
 'SEMNOME31',
 'SEMNOME32',
 'SEMNOME33',
 'SEMNOME34',
 'SEMNOME35',
 'SEMNOME36',
 'SEMNOME37',
 'SEMNOME38',
 'SEMNOME39',
 'SEMNOME40',
 'SEMNOME41',
 'SEMNOME42',
 'SEMNOME43',
 'SEMNOME44',
 'SEMNOME45',
 'SEMNOME46',
 'SEMNOME47',
 'SEMNOME48',
 'SEMNOME49',
 'SEMNOME50',
 'SEMNOME51',
 'SEMNOME52',
 'SEMNOME53',
 'SEMNOME54',
 'SEMNOME55',
 'SEMNOME56',
 'SEMNOME57',
 'SEMNOME58',
 'SEMNOME59',
 'SEMNOME60',
 'SEMNOME61',
 'SEMNOME62',
 'SEMNOME63',
 'SEMNOME64',
 'SEMNOME65',
 'SEMNOME66',
 'SEMNOME67',
 'SEMNOME68',
 'SEMNOME69',
 'SEMNOME70',
 'SEMNOME71',
 'SEMNOME72',
 'SEMNOME73',
 'SEMNOME74',
 'SEMNOME75',
 'SEMNOME76',
 'SEMNOME77',
 'SEMNOME78',
 'SEMNOME79',
 'SEMNOME80',
 'SEMNOME81',
 'SEMNOME82',
 'SEMNOME83',
 'SEMNOME84',
 'SEMNOME85',
 'SEMNOME86',
 'Decoy538',
 'SEMNOME87',
 'SEMNOME88',
 'SEMNOME89',
 'SEMNOME90',
 'SEMNOME91',
 'SEMNOME92',
 'SEMNOME93',
 'SEMNOME94',
 'SEMNOME95',
 'SEMNOME96',
 'SEMNOME97',
 'Decoy550',
 'SEMNOME98',
 'Decoy552',
 'Decoy553',
 'Decoy554',
 'Decoy555',
 'Decoy556',
 'Decoy557',
 'Decoy558',
 'Decoy559',
 'Decoy560',
 'Decoy561',
 'Decoy562',
 'Decoy563',
 'Decoy564',
 'Decoy565',
 'Decoy566',
 'Decoy567',
 'Decoy568',
 'Decoy569',
 'Decoy570',
 'Decoy571',
 'Decoy572',
 'Decoy573',
 'Decoy574',
 'Decoy575',
 'Decoy576',
 'Decoy577',
 'Decoy578',
 'Decoy579',
 'Decoy580',
 'Decoy581',
 'Decoy582',
 'Decoy583',
 'Decoy584',
 'Decoy585',
 'Decoy586',
 'Decoy587',
 'Decoy588',
 'Decoy589',
 'Decoy590',
 'Decoy591',
 'Decoy592',
 'Decoy593',
 'Decoy594',
 'Decoy595',
 'Decoy596',
 'Decoy597',
 'Decoy598',
 'Decoy599',
 'Decoy600',
 'Decoy601',
 'SEMNOME99',
 'SEMNOME100',
 'SEMNOME101',
 'SEMNOME102',
 'SEMNOME103',
 'SEMNOME104',
 'SEMNOME105',
 'SEMNOME106',
 'SEMNOME107',
 'SEMNOME108',
 'SEMNOME109',
 'SEMNOME110',
 'SEMNOME111',
 'SEMNOME112',
 'SEMNOME113',
 'SEMNOME114',
 'SEMNOME115',
 'SEMNOME116',
 'SEMNOME117',
 'SEMNOME118',
 'SEMNOME119',
 'SEMNOME120',
 'SEMNOME121',
 'SEMNOME122',
 'SEMNOME123',
 'SEMNOME123.1',
 'SEMNOME124',
 'SEMNOME125',
 'SEMNOME126',
 'SEMNOME127',
 'SEMNOME128',
 'SEMNOME129',
 'SEMNOME130',
 'SEMNOME131',
 'SEMNOME132',
 'SEMNOME133',
 'SEMNOME134',
 'SEMNOME135',
 'SEMNOME136',
 'SEMNOME137',
 'SEMNOME138',
 'SEMNOME139',
 'SEMNOME140',
 'SEMNOME141',
 'SEMNOME142',
 'SEMNOME143',
 'SEMNOME144',
 'SEMNOME145',
 'SEMNOME146',
 'SEMNOME147',
 'Decoy653',
 'Decoy654',
 'Decoy655',
 'Decoy656',
 'Decoy657',
 'Decoy658',
 'Decoy659',
 'Decoy660',
 'Decoy661',
 'Decoy662',
 'Decoy663',
 'Decoy664',
 'Decoy665',
 'Decoy666',
 'Decoy667',
 'Decoy668',
 'Decoy669',
 'Decoy670',
 'Decoy671',
 'Decoy672',
 'Decoy673',
 'Decoy674',
 'Decoy675',
 'Decoy676',
 'Decoy677',
 'Decoy678',
 'Decoy679',
 'Decoy680',
 'Decoy681',
 'Decoy682',
 'Decoy683',
 'Decoy684',
 'Decoy685',
 'Decoy686',
 'Decoy687',
 'Decoy688',
 'Decoy689',
 'Decoy690',
 'Decoy691',
 'Decoy692',
 'Decoy693',
 'Decoy694',
 'Decoy695',
 'Decoy696',
 'Decoy697',
 'Decoy698',
 'Decoy699',
 'Decoy700',
 'Decoy701',
 'Decoy702',
 'Decoy703',
 'Decoy704',
 'Decoy705',
 'Decoy706',
 'Decoy707',
 'Decoy708',
 'Decoy709',
 'Decoy710',
 'Decoy711',
 'Decoy712',
 'Decoy713',
 'Decoy714',
 'Decoy715',
 'Decoy716',
 'Decoy717',
 'Decoy718',
 'Decoy719',
 'Decoy720',
 'Decoy721',
 'Decoy722',
 'Decoy723',
 'Decoy724',
 'Decoy725',
 'Decoy726',
 'Decoy727',
 'Decoy728',
 'Decoy729',
 'Decoy730',
 'Decoy731',
 'Decoy732',
 'Decoy733',
 'Decoy734',
 'Decoy735',
 'Decoy736',
 'Decoy737',
 'Decoy738',
 'Decoy739',
 'Decoy740',
 'Decoy741',
 'Decoy742',
 'Decoy743',
 'Decoy744',
 'Decoy745',
 'Decoy746',
 'Decoy747',
 'Decoy748',
 'Decoy749',
 'Decoy750',
 'Decoy751',
 'Decoy752',
 'Decoy754',
 'Decoy755',
 'Decoy756',
 'Decoy757',
 'Decoy758',
 'Decoy759',
 'Decoy760',
 'Decoy761',
 'Decoy762',
 'Decoy763',
 'Decoy764',
 'Decoy765',
 'Decoy766',
 'Decoy767',
 'Decoy768',
 'Decoy769',
 'Decoy770',
 'Decoy771',
 'Decoy772',
 'Decoy773',
 'Decoy774',
 'Decoy775',
 'Decoy776',
 'Decoy777',
 'Decoy778',
 'Decoy779',
 'Decoy780',
 'Decoy781',
 'Decoy782',
 'Decoy783',
 'Decoy784',
 'Decoy785',
 'Decoy786',
 'Decoy787',
 'Decoy788',
 'Decoy789',
 'Decoy790',
 'Decoy791',
 'Decoy792',
 'Decoy793',
 'Decoy794',
 'Decoy795',
 'Decoy796',
 'Decoy797',
 'Decoy798',
 'Decoy799',
 'Decoy800',
 'Decoy801',
 'Decoy802',
 'Decoy803']

# %% [markdown]
# # Ligantes de Baccharis dracunculifolia

# %%
for l in ligantes:
    df.loc[df[l] == 1]
    print(l)
# Out:
# Decoy1
# Decoy2
# Decoy3
# Decoy4
# Decoy5
# Decoy6
# Decoy7
# Decoy8
# Decoy9
# Decoy10
# Decoy11
# Decoy12
# Decoy13
# Decoy14
# Decoy15
# Decoy16
# Decoy17
# Decoy18
# Decoy19
# Decoy20
# Decoy21
# Decoy22
# Decoy23
# Decoy24
# Decoy25
# Decoy26
# Decoy27
# Decoy28
# Decoy29
# Decoy30
# Decoy31
# Decoy32
# Decoy33
# Decoy34
# Decoy35
# Decoy36
# Decoy37
# Decoy38
# Decoy39
# Decoy40
# Decoy41
# Decoy42
# Decoy43
# Decoy44
# Decoy45
# Decoy46
# Decoy47
# Decoy48
# Decoy49
# Decoy50
# Decoy51
# Decoy52
# Decoy53
# Decoy54
# Decoy55
# Decoy56
# Decoy57
# Decoy58
# Decoy59
# Decoy60
# Decoy61
# Decoy62
# Decoy63
# Decoy64
# Decoy65
# Decoy66
# Decoy67
# Decoy68
# Decoy69
# Decoy70
# Decoy71
# Decoy72
# Decoy73
# Decoy74
# Decoy75
# Decoy76
# Decoy77
# Decoy78
# Decoy79
# Decoy80
# Decoy81
# Decoy82
# Decoy83
# Decoy84
# Decoy85
# Decoy86
# Decoy87
# Decoy88
# Decoy89
# Decoy90
# Decoy91
# Decoy92
# Decoy93
# Decoy94
# Decoy95
# Decoy96
# Decoy97
# Decoy98
# Decoy99
# Decoy100
# ...

# %%
df.loc[df['Decoy4'] == 1]
# Out:
#           Decoy1    Decoy2    Decoy3  Decoy4    Decoy5    Decoy6    Decoy7  \
# Decoy4  0.409915  0.378961  0.476589     1.0  0.340878  0.360751  0.342466
#
#           Decoy8    Decoy9   Decoy10  ...  Decoy794  Decoy795  Decoy796  \
# Decoy4  0.341656  0.348374  0.372804  ...  0.179845  0.171561  0.168053
#
#         Decoy797  Decoy798  Decoy799  Decoy800  Decoy801  Decoy802  Decoy803
# Decoy4  0.103161  0.241248  0.083333  0.183917  0.109091  0.210324  0.179046
#
# [1 rows x 800 columns]

# %%
df.loc[df['beta-Pinene'] == 1]
# Out:
#                alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# beta-Pinene        0.653509   0.62069          1.0  0.121359  0.346667
# beta-Pinene        0.653509   0.62069          1.0  0.121359  0.346667
# Ligand8            0.653509   0.62069          1.0  0.121359  0.346667
# ZINC967582         0.653509   0.62069          1.0  0.121359  0.346667
# ZINC1530385        0.653509   0.62069          1.0  0.121359  0.346667
# ZINC100020236      0.653509   0.62069          1.0  0.121359  0.346667
# ZINC100040119      0.653509   0.62069          1.0  0.121359  0.346667
#
#                (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# beta-Pinene             0.689498      0.321138            0.412639
# beta-Pinene             0.689498      0.321138            0.412639
# Ligand8                 0.689498      0.321138            0.412639
# ZINC967582              0.689498      0.321138            0.412639
# ...

# %%
df.loc[df['Myrcene'] == 1]
# Out:
#               alpha-Pinene  Sabinene  beta-Pinene  Myrcene  Limonene  \
# Myrcene           0.181034  0.109756     0.121359      1.0  0.369863
# Myrcene           0.181034  0.109756     0.121359      1.0  0.369863
# beta-Myrcene      0.181034  0.109756     0.121359      1.0  0.369863
# ZINC1530331       0.181034  0.109756     0.121359      1.0  0.369863
# ZINC1530331       0.181034  0.109756     0.121359      1.0  0.369863
#
#               (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Myrcene                 0.24186      0.405063            0.236607
# Myrcene                 0.24186      0.405063            0.236607
# beta-Myrcene            0.24186      0.405063            0.236607
# ZINC1530331             0.24186      0.405063            0.236607
# ZINC1530331             0.24186      0.405063            0.236607
#
#               Bicyclogermacrene2  Bicyclogermacrene3  ...  ZINC12358780  \
# Myrcene                 0.236607            0.236607  ...      0.064356
# ...

# %%
df.loc[df['Limonene'] == 1]
# Out:
#             alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Limonene        0.484979  0.287313     0.346667  0.369863       1.0
# Limonene        0.484979  0.287313     0.346667  0.369863       1.0
# ZINC967513      0.484979  0.287313     0.346667  0.369863       1.0
# ZINC968226      0.484979  0.287313     0.346667  0.369863       1.0
# ZINC968226      0.484979  0.287313     0.346667  0.369863       1.0
#
#             (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Limonene                  0.5      0.615385            0.454167
# Limonene                  0.5      0.615385            0.454167
# ZINC967513                0.5      0.615385            0.454167
# ZINC968226                0.5      0.615385            0.454167
# ZINC968226                0.5      0.615385            0.454167
#
#             Bicyclogermacrene2  Bicyclogermacrene3  ...  ZINC12358780  \
# Limonene              0.454167            0.454167  ...      0.059041
# ...

# %%
df.loc[df['(E)-Caryophyllene'] == 1]
# Out:
#                    alpha-Pinene  Sabinene  beta-Pinene  Myrcene  Limonene  \
# (E)-Caryophyllene      0.678862  0.514706     0.689498  0.24186       0.5
# (E)-Caryophyllene      0.678862  0.514706     0.689498  0.24186       0.5
# (E)-Caryophyllene      0.678862  0.514706     0.689498  0.24186       0.5
# ZINC8234282            0.678862  0.514706     0.689498  0.24186       0.5
# ZINC30726969           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC49538668           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC49586678           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC49586679           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC51421382           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC30726969           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC8234282            0.678862  0.514706     0.689498  0.24186       0.5
# ZINC8234282            0.678862  0.514706     0.689498  0.24186       0.5
# ...

# %%
df.loc[df['Germacrene-D'] == 1]
# Out:
#                alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Germacrene-D       0.460317  0.269896     0.321138  0.405063  0.615385
# Germacrene_D       0.460317  0.269896     0.321138  0.405063  0.615385
# Germacrene-D       0.460317  0.269896     0.321138  0.405063  0.615385
# ZINC30730221       0.460317  0.269896     0.321138  0.405063  0.615385
# ZINC62592241       0.460317  0.269896     0.321138  0.405063  0.615385
# ZINC62592242       0.460317  0.269896     0.321138  0.405063  0.615385
# ZINC111399202      0.460317  0.269896     0.321138  0.405063  0.615385
#
#                (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Germacrene-D            0.473469           1.0            0.520492
# Germacrene_D            0.473469           1.0            0.520492
# Germacrene-D            0.473469           1.0            0.520492
# ZINC30730221            0.473469           1.0            0.520492
# ...

# %%
df.loc[df['Bicyclogermacrene1'] == 1]
# Out:
#                     alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100086523           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100826334           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC101785466           0.560886  0.455172     0.412639  0.236607  0.454167
# ...

# %%
df.loc[df['Bicyclogermacrene2'] == 1]
# Out:
#                     alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100086523           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100826334           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC101785466           0.560886  0.455172     0.412639  0.236607  0.454167
# ...

# %%
df.loc[df['Bicyclogermacrene3'] == 1]
# Out:
#                     alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100086523           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100826334           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC101785466           0.560886  0.455172     0.412639  0.236607  0.454167
# ...

# %%
df.loc[df['Bicyclogermacrene4'] == 1]
# Out:
#                     alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100086523           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100826334           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC101785466           0.560886  0.455172     0.412639  0.236607  0.454167
# ...

# %%
df.loc[df['Delta-Cadinene1'] == 1]
# Out:
#                  alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# ZINC8220462               0.5  0.344928      0.36129  0.212928  0.481061
# ZINC85600726              0.5  0.344928      0.36129  0.212928  0.481061
# ZINC8220462               0.5  0.344928      0.36129  0.212928  0.481061
#
#                  (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Delta-Cadinene1           0.526667      0.496377            0.471698
# Delta-Cadinene2           0.526667      0.496377            0.471698
# ...

# %%
df.loc[df['Delta-Cadinene2'] == 1]
# Out:
#                  alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# ZINC8220462               0.5  0.344928      0.36129  0.212928  0.481061
# ZINC85600726              0.5  0.344928      0.36129  0.212928  0.481061
# ZINC8220462               0.5  0.344928      0.36129  0.212928  0.481061
#
#                  (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Delta-Cadinene1           0.526667      0.496377            0.471698
# Delta-Cadinene2           0.526667      0.496377            0.471698
# ...

# %%
df.loc[df['(E)-Nerolidol'] == 1]
# Out:
#                alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# (E)-Nerolidol      0.245421  0.149153     0.160156  0.385714  0.414894
# ZINC1531550        0.245421  0.149153     0.160156  0.385714  0.414894
# ZINC2040970        0.245421  0.149153     0.160156  0.385714  0.414894
# ZINC13319968       0.245421  0.149153     0.160156  0.385714  0.414894
#
#                (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# (E)-Nerolidol           0.311024       0.37799            0.304183
# ZINC1531550             0.311024       0.37799            0.304183
# ZINC2040970             0.311024       0.37799            0.304183
# ZINC13319968            0.311024       0.37799            0.304183
#
#                Bicyclogermacrene2  Bicyclogermacrene3  ...  ZINC12358780  \
# (E)-Nerolidol            0.304183            0.304183  ...      0.084942
# ZINC1531550              0.304183            0.304183  ...      0.084942
# ...

# %%
df.loc[df['Spathulenol1'] == 1]
# Out:
#               alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Spathulenol1      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol2      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol3      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol4      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol5      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol6      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol7      0.328165  0.474138     0.393491  0.082353  0.222222
# Ligand24          0.328165  0.474138     0.393491  0.082353  0.222222
#
#               (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Spathulenol1           0.392857      0.222222            0.360526
# Spathulenol2           0.392857      0.222222            0.360526
# Spathulenol3           0.392857      0.222222            0.360526
# Spathulenol4           0.392857      0.222222            0.360526
# ...

# %%
df.loc[df['Spathulenol2'] == 1]
# Out:
#               alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Spathulenol1      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol2      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol3      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol4      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol5      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol6      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol7      0.328165  0.474138     0.393491  0.082353  0.222222
# Ligand24          0.328165  0.474138     0.393491  0.082353  0.222222
#
#               (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Spathulenol1           0.392857      0.222222            0.360526
# Spathulenol2           0.392857      0.222222            0.360526
# Spathulenol3           0.392857      0.222222            0.360526
# Spathulenol4           0.392857      0.222222            0.360526
# ...

# %%
df.loc[df['Spathulenol3'] == 1]
# Out:
#               alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Spathulenol1      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol2      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol3      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol4      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol5      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol6      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol7      0.328165  0.474138     0.393491  0.082353  0.222222
# Ligand24          0.328165  0.474138     0.393491  0.082353  0.222222
#
#               (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Spathulenol1           0.392857      0.222222            0.360526
# Spathulenol2           0.392857      0.222222            0.360526
# Spathulenol3           0.392857      0.222222            0.360526
# Spathulenol4           0.392857      0.222222            0.360526
# ...

# %%
df.loc[df['Spathulenol4'] == 1]
# Out:
#               alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Spathulenol1      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol2      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol3      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol4      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol5      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol6      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol7      0.328165  0.474138     0.393491  0.082353  0.222222
# Ligand24          0.328165  0.474138     0.393491  0.082353  0.222222
#
#               (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Spathulenol1           0.392857      0.222222            0.360526
# Spathulenol2           0.392857      0.222222            0.360526
# Spathulenol3           0.392857      0.222222            0.360526
# Spathulenol4           0.392857      0.222222            0.360526
# ...

# %%
df.loc[df['Spathulenol5'] == 1]
# Out:
#               alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Spathulenol1      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol2      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol3      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol4      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol5      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol6      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol7      0.328165  0.474138     0.393491  0.082353  0.222222
# Ligand24          0.328165  0.474138     0.393491  0.082353  0.222222
#
#               (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Spathulenol1           0.392857      0.222222            0.360526
# Spathulenol2           0.392857      0.222222            0.360526
# Spathulenol3           0.392857      0.222222            0.360526
# Spathulenol4           0.392857      0.222222            0.360526
# ...

# %%
df.loc[df['Spathulenol6'] == 1]
# Out:
#               alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Spathulenol1      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol2      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol3      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol4      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol5      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol6      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol7      0.328165  0.474138     0.393491  0.082353  0.222222
# Ligand24          0.328165  0.474138     0.393491  0.082353  0.222222
#
#               (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Spathulenol1           0.392857      0.222222            0.360526
# Spathulenol2           0.392857      0.222222            0.360526
# Spathulenol3           0.392857      0.222222            0.360526
# Spathulenol4           0.392857      0.222222            0.360526
# ...

# %%
df.loc[df['Spathulenol7'] == 1]
# Out:
#               alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Spathulenol1      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol2      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol3      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol4      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol5      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol6      0.328165  0.474138     0.393491  0.082353  0.222222
# Spathulenol7      0.328165  0.474138     0.393491  0.082353  0.222222
# Ligand24          0.328165  0.474138     0.393491  0.082353  0.222222
#
#               (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Spathulenol1           0.392857      0.222222            0.360526
# Spathulenol2           0.392857      0.222222            0.360526
# Spathulenol3           0.392857      0.222222            0.360526
# Spathulenol4           0.392857      0.222222            0.360526
# ...

# %%
df.loc[df['Caryophyllene_oxide1'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide2'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide3'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide4'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide5'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide6'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide7'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide8'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %% [markdown]
# # Ligantes de Baccharis retusa

# %%
df.loc[df['alpha-Thujene'] == 1]
# Out:
#                alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# alpha-Thujene      0.643382  0.587189     0.432624  0.166667  0.412879
# ZINC2035755        0.643382  0.587189     0.432624  0.166667  0.412879
#
#                (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# alpha-Thujene           0.506849      0.390845            0.618705
# ZINC2035755             0.506849      0.390845            0.618705
#
#                Bicyclogermacrene2  Bicyclogermacrene3  ...  ZINC12358780  \
# alpha-Thujene            0.618705            0.618705  ...      0.054348
# ZINC2035755              0.618705            0.618705  ...      0.054348
#
#                ZINC967635  ZINC1676040  ZINC1599076  ZINC5158074  ZINC1529247  \
# alpha-Thujene    0.047368     0.388379     0.069597     0.130699     0.051587
# ZINC2035755      0.047368     0.388379     0.069597     0.130699     0.051587
#
#                ZINC1532735  ZINC2512204  ZINC1653216  Unnamed: 341
# ...

# %%
df.loc[df['alpha-Pinene.1'] == 1]
# Out:
#                alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# alpha-Pinene            1.0   0.45993     0.653509  0.181034  0.484979
# alpha-Pinene            1.0   0.45993     0.653509  0.181034  0.484979
# alpha-Pinene            1.0   0.45993     0.653509  0.181034  0.484979
# Ligand6                 1.0   0.45993     0.653509  0.181034  0.484979
# ZINC967579              1.0   0.45993     0.653509  0.181034  0.484979
# ZINC967580              1.0   0.45993     0.653509  0.181034  0.484979
# ZINC100024169           1.0   0.45993     0.653509  0.181034  0.484979
# ZINC100024175           1.0   0.45993     0.653509  0.181034  0.484979
#
#                (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# alpha-Pinene            0.678862      0.460317            0.560886
# alpha-Pinene            0.678862      0.460317            0.560886
# alpha-Pinene            0.678862      0.460317            0.560886
# ...

# %%
df.loc[df['beta-Pinene.1'] == 1]
# Out:
#                alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# beta-Pinene        0.653509   0.62069          1.0  0.121359  0.346667
# beta-Pinene        0.653509   0.62069          1.0  0.121359  0.346667
# Ligand8            0.653509   0.62069          1.0  0.121359  0.346667
# ZINC967582         0.653509   0.62069          1.0  0.121359  0.346667
# ZINC1530385        0.653509   0.62069          1.0  0.121359  0.346667
# ZINC100020236      0.653509   0.62069          1.0  0.121359  0.346667
# ZINC100040119      0.653509   0.62069          1.0  0.121359  0.346667
#
#                (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# beta-Pinene             0.689498      0.321138            0.412639
# beta-Pinene             0.689498      0.321138            0.412639
# Ligand8                 0.689498      0.321138            0.412639
# ZINC967582              0.689498      0.321138            0.412639
# ...

# %%
df.loc[df['Myrcene.1'] == 1]
# Out:
#               alpha-Pinene  Sabinene  beta-Pinene  Myrcene  Limonene  \
# Myrcene           0.181034  0.109756     0.121359      1.0  0.369863
# Myrcene           0.181034  0.109756     0.121359      1.0  0.369863
# beta-Myrcene      0.181034  0.109756     0.121359      1.0  0.369863
# ZINC1530331       0.181034  0.109756     0.121359      1.0  0.369863
# ZINC1530331       0.181034  0.109756     0.121359      1.0  0.369863
#
#               (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Myrcene                 0.24186      0.405063            0.236607
# Myrcene                 0.24186      0.405063            0.236607
# beta-Myrcene            0.24186      0.405063            0.236607
# ZINC1530331             0.24186      0.405063            0.236607
# ZINC1530331             0.24186      0.405063            0.236607
#
#               Bicyclogermacrene2  Bicyclogermacrene3  ...  ZINC12358780  \
# Myrcene                 0.236607            0.236607  ...      0.064356
# ...

# %%
df.loc[df['(E)-Caryophyllene.1'] == 1]
# Out:
#                    alpha-Pinene  Sabinene  beta-Pinene  Myrcene  Limonene  \
# (E)-Caryophyllene      0.678862  0.514706     0.689498  0.24186       0.5
# (E)-Caryophyllene      0.678862  0.514706     0.689498  0.24186       0.5
# (E)-Caryophyllene      0.678862  0.514706     0.689498  0.24186       0.5
# ZINC8234282            0.678862  0.514706     0.689498  0.24186       0.5
# ZINC30726969           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC49538668           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC49586678           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC49586679           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC51421382           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC30726969           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC8234282            0.678862  0.514706     0.689498  0.24186       0.5
# ZINC8234282            0.678862  0.514706     0.689498  0.24186       0.5
# ...

# %%
df.loc[df['Delta-Cadinene1.1'] == 1]
# Out:
#                  alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# ZINC8220462               0.5  0.344928      0.36129  0.212928  0.481061
# ZINC85600726              0.5  0.344928      0.36129  0.212928  0.481061
# ZINC8220462               0.5  0.344928      0.36129  0.212928  0.481061
#
#                  (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Delta-Cadinene1           0.526667      0.496377            0.471698
# Delta-Cadinene2           0.526667      0.496377            0.471698
# ...

# %%
df.loc[df['Delta-Cadinene2.1'] == 1]
# Out:
#                  alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# ZINC8220462               0.5  0.344928      0.36129  0.212928  0.481061
# ZINC85600726              0.5  0.344928      0.36129  0.212928  0.481061
# ZINC8220462               0.5  0.344928      0.36129  0.212928  0.481061
#
#                  (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Delta-Cadinene1           0.526667      0.496377            0.471698
# Delta-Cadinene2           0.526667      0.496377            0.471698
# ...

# %%
df.loc[df['Caryophyllene_oxide1.1'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide2.1'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide3.1'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide4.1'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide5.1'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide6.1'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide7.1'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %%
df.loc[df['Caryophyllene_oxide8.1'] == 1]
# Out:
#                       alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide4       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide5       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide6       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide7       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide8       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide1       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide2       0.38874  0.386059     0.466049  0.078261   0.22314
# Caryophyllene_oxide3       0.38874  0.386059     0.466049  0.078261   0.22314
# ...

# %% [markdown]
# # ligantes de Disynaphia spathulata

# %%
df.loc[df['alpha-Pinene.2'] == 1]
# Out:
#                alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# alpha-Pinene            1.0   0.45993     0.653509  0.181034  0.484979
# alpha-Pinene            1.0   0.45993     0.653509  0.181034  0.484979
# alpha-Pinene            1.0   0.45993     0.653509  0.181034  0.484979
# Ligand6                 1.0   0.45993     0.653509  0.181034  0.484979
# ZINC967579              1.0   0.45993     0.653509  0.181034  0.484979
# ZINC967580              1.0   0.45993     0.653509  0.181034  0.484979
# ZINC100024169           1.0   0.45993     0.653509  0.181034  0.484979
# ZINC100024175           1.0   0.45993     0.653509  0.181034  0.484979
#
#                (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# alpha-Pinene            0.678862      0.460317            0.560886
# alpha-Pinene            0.678862      0.460317            0.560886
# alpha-Pinene            0.678862      0.460317            0.560886
# ...

# %%
df.loc[df['beta-Myrcene'] == 1]
# Out:
#               alpha-Pinene  Sabinene  beta-Pinene  Myrcene  Limonene  \
# Myrcene           0.181034  0.109756     0.121359      1.0  0.369863
# Myrcene           0.181034  0.109756     0.121359      1.0  0.369863
# beta-Myrcene      0.181034  0.109756     0.121359      1.0  0.369863
# ZINC1530331       0.181034  0.109756     0.121359      1.0  0.369863
# ZINC1530331       0.181034  0.109756     0.121359      1.0  0.369863
#
#               (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Myrcene                 0.24186      0.405063            0.236607
# Myrcene                 0.24186      0.405063            0.236607
# beta-Myrcene            0.24186      0.405063            0.236607
# ZINC1530331             0.24186      0.405063            0.236607
# ZINC1530331             0.24186      0.405063            0.236607
#
#               Bicyclogermacrene2  Bicyclogermacrene3  ...  ZINC12358780  \
# Myrcene                 0.236607            0.236607  ...      0.064356
# ...

# %%
df.loc[df['Limonene.1'] == 1]
# Out:
#             alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Limonene        0.484979  0.287313     0.346667  0.369863       1.0
# Limonene        0.484979  0.287313     0.346667  0.369863       1.0
# ZINC967513      0.484979  0.287313     0.346667  0.369863       1.0
# ZINC968226      0.484979  0.287313     0.346667  0.369863       1.0
# ZINC968226      0.484979  0.287313     0.346667  0.369863       1.0
#
#             (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Limonene                  0.5      0.615385            0.454167
# Limonene                  0.5      0.615385            0.454167
# ZINC967513                0.5      0.615385            0.454167
# ZINC968226                0.5      0.615385            0.454167
# ZINC968226                0.5      0.615385            0.454167
#
#             Bicyclogermacrene2  Bicyclogermacrene3  ...  ZINC12358780  \
# Limonene              0.454167            0.454167  ...      0.059041
# ...

# %%
df.loc[df['(E)-beta-Ocimene'] == 1]
# Out:
#                   alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# (E)-beta-Ocimene      0.085106  0.053942         0.06  0.282353  0.124224
# ZINC1531619           0.085106  0.053942         0.06  0.282353  0.124224
# ZINC1531619           0.085106  0.053942         0.06  0.282353  0.124224
#
#                   (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# (E)-beta-Ocimene           0.087719          0.16             0.09322
# ZINC1531619                0.087719          0.16             0.09322
# ZINC1531619                0.087719          0.16             0.09322
#
#                   Bicyclogermacrene2  Bicyclogermacrene3  ...  ZINC12358780  \
# (E)-beta-Ocimene             0.09322             0.09322  ...      0.048128
# ZINC1531619                  0.09322             0.09322  ...      0.048128
# ZINC1531619                  0.09322             0.09322  ...      0.048128
#
#                   ZINC967635  ZINC1676040  ZINC1599076  ZINC5158074  \
# ...

# %%
df.loc[df['(E)-Caryophyllene.2'] == 1]
# Out:
#                    alpha-Pinene  Sabinene  beta-Pinene  Myrcene  Limonene  \
# (E)-Caryophyllene      0.678862  0.514706     0.689498  0.24186       0.5
# (E)-Caryophyllene      0.678862  0.514706     0.689498  0.24186       0.5
# (E)-Caryophyllene      0.678862  0.514706     0.689498  0.24186       0.5
# ZINC8234282            0.678862  0.514706     0.689498  0.24186       0.5
# ZINC30726969           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC49538668           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC49586678           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC49586679           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC51421382           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC30726969           0.678862  0.514706     0.689498  0.24186       0.5
# ZINC8234282            0.678862  0.514706     0.689498  0.24186       0.5
# ZINC8234282            0.678862  0.514706     0.689498  0.24186       0.5
# ...

# %%
df.loc[df['alpha-Humulene'] == 1]
# Out:
#                 alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# alpha-Humulene         0.336  0.164336     0.192623  0.392593  0.452514
# ZINC38139375           0.336  0.164336     0.192623  0.392593  0.452514
# ZINC30726967           0.336  0.164336     0.192623  0.392593  0.452514
# ZINC38139375           0.336  0.164336     0.192623  0.392593  0.452514
#
#                 (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# alpha-Humulene           0.334694      0.453608             0.39834
# ZINC38139375             0.334694      0.453608             0.39834
# ZINC30726967             0.334694      0.453608             0.39834
# ZINC38139375             0.334694      0.453608             0.39834
#
#                 Bicyclogermacrene2  Bicyclogermacrene3  ...  ZINC12358780  \
# alpha-Humulene             0.39834             0.39834  ...      0.074219
# ZINC38139375               0.39834             0.39834  ...      0.074219
# ...

# %%
df.loc[df['Germacrene-D.1'] == 1]
# Out:
#                alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Germacrene-D       0.460317  0.269896     0.321138  0.405063  0.615385
# Germacrene_D       0.460317  0.269896     0.321138  0.405063  0.615385
# Germacrene-D       0.460317  0.269896     0.321138  0.405063  0.615385
# ZINC30730221       0.460317  0.269896     0.321138  0.405063  0.615385
# ZINC62592241       0.460317  0.269896     0.321138  0.405063  0.615385
# ZINC62592242       0.460317  0.269896     0.321138  0.405063  0.615385
# ZINC111399202      0.460317  0.269896     0.321138  0.405063  0.615385
#
#                (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Germacrene-D            0.473469           1.0            0.520492
# Germacrene_D            0.473469           1.0            0.520492
# Germacrene-D            0.473469           1.0            0.520492
# ZINC30730221            0.473469           1.0            0.520492
# ...

# %%
df.loc[df['Bicyclogermacrene1.1'] == 1]
# Out:
#                     alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100086523           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100826334           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC101785466           0.560886  0.455172     0.412639  0.236607  0.454167
# ...

# %%
df.loc[df['Bicyclogermacrene2.1'] == 1]
# Out:
#                     alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100086523           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100826334           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC101785466           0.560886  0.455172     0.412639  0.236607  0.454167
# ...

# %%
df.loc[df['Bicyclogermacrene3.1'] == 1]
# Out:
#                     alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100086523           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100826334           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC101785466           0.560886  0.455172     0.412639  0.236607  0.454167
# ...

# %%
df.loc[df['Bicyclogermacrene4.1'] == 1]
# Out:
#                     alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene1      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene2      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene3      0.560886  0.455172     0.412639  0.236607  0.454167
# Bicyclogermacrene4      0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100086523           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC100826334           0.560886  0.455172     0.412639  0.236607  0.454167
# ZINC101785466           0.560886  0.455172     0.412639  0.236607  0.454167
# ...

# %%
df.loc[df['Delta-Cadinene1.2'] == 1]
# Out:
#                  alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# ZINC8220462               0.5  0.344928      0.36129  0.212928  0.481061
# ZINC85600726              0.5  0.344928      0.36129  0.212928  0.481061
# ZINC8220462               0.5  0.344928      0.36129  0.212928  0.481061
#
#                  (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Delta-Cadinene1           0.526667      0.496377            0.471698
# Delta-Cadinene2           0.526667      0.496377            0.471698
# ...

# %%
df.loc[df['Delta-Cadinene2.2'] == 1]
# Out:
#                  alpha-Pinene  Sabinene  beta-Pinene   Myrcene  Limonene  \
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene1           0.5  0.344928      0.36129  0.212928  0.481061
# Delta-Cadinene2           0.5  0.344928      0.36129  0.212928  0.481061
# ZINC8220462               0.5  0.344928      0.36129  0.212928  0.481061
# ZINC85600726              0.5  0.344928      0.36129  0.212928  0.481061
# ZINC8220462               0.5  0.344928      0.36129  0.212928  0.481061
#
#                  (E)-Caryophyllene  Germacrene-D  Bicyclogermacrene1  \
# Delta-Cadinene1           0.526667      0.496377            0.471698
# Delta-Cadinene2           0.526667      0.496377            0.471698
# ...
